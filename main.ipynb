# %%
from mss import mss
import cv2
import numpy as np
import time
import pyautogui
import pytesseract
from matplotlib import pyplot as plt
import gymnasium as gym
from gym import Env 
from gymnasium import spaces
import os
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common import env_checker
from stable_baselines3 import DQN

# %%
class DinoWeb(gym.Env):
    def __init__(self):
        super().__init__()
        self.action_space = spaces.Discrete(3)
        self.observation_space = spaces.Box(low=0, high=255, shape=(1, 83, 100), dtype=np.float32)
        self.cap = mss()
        self.game_location = {"top": 300, "left": 0, "width": 600, "height": 500}
        self.done_location = {"top": 405, "left": 430, "width": 600, "height": 50}
        self.done_pixel = (666, 411)
    def step(self, action):
        action_map = {0: 'up', 1: 'down', 2: 'none'}
        if action != 2:
            pyautogui.press(action_map[action])
        done, done_cap = self.get_done()
        obs = self.get_observation()
        reward = 1
        info = {}

        return obs, reward, done, False, info

    def render(self):
        cv2.imshow('Dino', np.array(self.cap.grab(self.game_location))[:,:,:3])
        if cv2.waitKey(1) & 0xFF == ord('q'):
            self.close()

    def reset(self, seed=None, options=None):
        time.sleep(1.5)
        pyautogui.click(300, 300)
        pyautogui.press('space')
        return self.get_observation(), {}

    def close(self):
        cv2.destroyAllWindows()
        cv2.waitKey(1)

    def get_observation(self):
        raw = np.array(self.cap.grab(self.game_location))[:,:,:3]
        gray = cv2.cvtColor(raw, cv2.COLOR_BGR2GRAY)
        resized = cv2.resize(gray, (100, 83))
        channel = np.reshape(resized, (1, 83, 100)).astype(np.float32)
        return channel

    def get_done(self):
        screen = np.array(self.cap.grab(self.done_location))[:,:,:3]
        done_pixel_color = screen[15, 400]
        done = False

        # Check if the pixel color matches the game over color
        if np.array_equal(done_pixel_color, [83, 83, 83]):  # Replace with the actual game over color
            done = True
        return done, done_pixel_color

# %%
env_checker.check_env(env)
# Out:
# /Users/plg/Documents/UQAC/Apprentissage Profond/AI using Pygame/.venv/lib/python3.12/site-packages/stable_baselines3/common/env_checker.py:54: UserWarning: It seems that your observation  is an image but its `dtype` is (float32) whereas it has to be `np.uint8`. If your observation is not an image, we recommend you to flatten the observation to have only a 1D vector
#   warnings.warn(

# %%
class TrainAndLoggingCallback(BaseCallback):
    def __init__(self, check_freq, save_path,verbose=0):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'moddel{}'.format(self.n_calls))
            self.model.save(model_path)
            
        return True

# %%
CHECKPOINT_DIR = './train/'
LOG_DIR = './logs/'

# %%
callback = TrainAndLoggingCallback(check_freq=1000, save_path=CHECKPOINT_DIR)

# %%
model = DQN('CnnPolicy', env, tensorboard_log=LOG_DIR, verbose=1, buffer_size=300000, learning_starts=1000,policy_kwargs=dict(normalize_images=False))
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /Users/plg/Documents/UQAC/Apprentissage Profond/AI using Pygame/.venv/lib/python3.12/site-packages/stable_baselines3/common/buffers.py:241: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 19.92GB > 7.03GB
#   warnings.warn(

# %%
model.learn(total_timesteps=100000, callback=callback)
# Out:
# Logging to ./logs/DQN_3
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.8     |
# |    ep_rew_mean      | 36.8     |
# |    exploration_rate | 0.986    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 5        |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 147      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 43.5     |
# |    ep_rew_mean      | 43.5     |
# |    exploration_rate | 0.967    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 5        |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 348      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 47.6     |
# |    ep_rew_mean      | 47.6     |
# |    exploration_rate | 0.946    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 5        |
# |    time_elapsed     | 96       |
# |    total_timesteps  | 571      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 45.8     |
# |    ep_rew_mean      | 45.8     |
# |    exploration_rate | 0.93     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 5        |
# |    time_elapsed     | 125      |
# |    total_timesteps  | 733      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 44.8     |
# |    ep_rew_mean      | 44.8     |
# |    exploration_rate | 0.915    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 5        |
# |    time_elapsed     | 152      |
# |    total_timesteps  | 895      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 46.8     |
# |    ep_rew_mean      | 46.8     |
# |    exploration_rate | 0.893    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 5        |
# |    time_elapsed     | 187      |
# |    total_timesteps  | 1123     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0391   |
# |    n_updates        | 30       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 45.3     |
# |    ep_rew_mean      | 45.3     |
# |    exploration_rate | 0.879    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 5        |
# |    time_elapsed     | 214      |
# |    total_timesteps  | 1269     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0459   |
# |    n_updates        | 67       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 44.9     |
# |    ep_rew_mean      | 44.9     |
# |    exploration_rate | 0.863    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 5        |
# |    time_elapsed     | 243      |
# |    total_timesteps  | 1438     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0314   |
# |    n_updates        | 109      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 44.2     |
# |    ep_rew_mean      | 44.2     |
# |    exploration_rate | 0.849    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 5        |
# |    time_elapsed     | 271      |
# |    total_timesteps  | 1592     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.024    |
# |    n_updates        | 147      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 45       |
# |    ep_rew_mean      | 45       |
# |    exploration_rate | 0.829    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 5        |
# |    time_elapsed     | 304      |
# |    total_timesteps  | 1801     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0269   |
# |    n_updates        | 200      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 44.8     |
# |    ep_rew_mean      | 44.8     |
# |    exploration_rate | 0.813    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 5        |
# |    time_elapsed     | 334      |
# |    total_timesteps  | 1970     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0177   |
# |    n_updates        | 242      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 44.8     |
# |    ep_rew_mean      | 44.8     |
# |    exploration_rate | 0.796    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 5        |
# |    time_elapsed     | 364      |
# |    total_timesteps  | 2151     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0135   |
# |    n_updates        | 287      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 45.2     |
# |    ep_rew_mean      | 45.2     |
# |    exploration_rate | 0.777    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 5        |
# |    time_elapsed     | 394      |
# |    total_timesteps  | 2349     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0177   |
# |    n_updates        | 337      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 44.7     |
# |    ep_rew_mean      | 44.7     |
# |    exploration_rate | 0.762    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 5        |
# |    time_elapsed     | 421      |
# |    total_timesteps  | 2501     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0113   |
# |    n_updates        | 375      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 44.2     |
# |    ep_rew_mean      | 44.2     |
# |    exploration_rate | 0.748    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 5        |
# |    time_elapsed     | 448      |
# |    total_timesteps  | 2654     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0262   |
# |    n_updates        | 413      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 44.6     |
# |    ep_rew_mean      | 44.6     |
# |    exploration_rate | 0.729    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 5        |
# |    time_elapsed     | 480      |
# |    total_timesteps  | 2855     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0245   |
# |    n_updates        | 463      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 44.4     |
# |    ep_rew_mean      | 44.4     |
# |    exploration_rate | 0.713    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 5        |
# |    time_elapsed     | 507      |
# |    total_timesteps  | 3021     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0186   |
# |    n_updates        | 505      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 44       |
# |    ep_rew_mean      | 44       |
# |    exploration_rate | 0.699    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 5        |
# |    time_elapsed     | 532      |
# |    total_timesteps  | 3165     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0329   |
# |    n_updates        | 541      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 44.2     |
# |    ep_rew_mean      | 44.2     |
# |    exploration_rate | 0.681    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 5        |
# |    time_elapsed     | 563      |
# |    total_timesteps  | 3357     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.023    |
# |    n_updates        | 589      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 44.1     |
# |    ep_rew_mean      | 44.1     |
# |    exploration_rate | 0.665    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 5        |
# |    time_elapsed     | 591      |
# |    total_timesteps  | 3528     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.017    |
# |    n_updates        | 631      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 43.7     |
# |    ep_rew_mean      | 43.7     |
# |    exploration_rate | 0.651    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 5        |
# |    time_elapsed     | 618      |
# |    total_timesteps  | 3669     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0196   |
# |    n_updates        | 667      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 43.5     |
# |    ep_rew_mean      | 43.5     |
# |    exploration_rate | 0.637    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 5        |
# |    time_elapsed     | 643      |
# |    total_timesteps  | 3825     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00967  |
# |    n_updates        | 706      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 43.6     |
# |    ep_rew_mean      | 43.6     |
# |    exploration_rate | 0.619    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 5        |
# |    time_elapsed     | 673      |
# |    total_timesteps  | 4009     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.021    |
# |    n_updates        | 752      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 43.5     |
# |    ep_rew_mean      | 43.5     |
# |    exploration_rate | 0.603    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 5        |
# |    time_elapsed     | 701      |
# |    total_timesteps  | 4175     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0107   |
# |    n_updates        | 793      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 43.7     |
# |    ep_rew_mean      | 43.7     |
# |    exploration_rate | 0.585    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 5        |
# |    time_elapsed     | 731      |
# |    total_timesteps  | 4369     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0133   |
# |    n_updates        | 842      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 43.8     |
# |    ep_rew_mean      | 43.8     |
# |    exploration_rate | 0.57     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 5        |
# |    time_elapsed     | 758      |
# |    total_timesteps  | 4528     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0113   |
# |    n_updates        | 881      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 43.5     |
# |    ep_rew_mean      | 43.5     |
# |    exploration_rate | 0.554    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 5        |
# |    time_elapsed     | 786      |
# |    total_timesteps  | 4695     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0154   |
# |    n_updates        | 923      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42.8     |
# |    ep_rew_mean      | 42.8     |
# |    exploration_rate | 0.539    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 5        |
# |    time_elapsed     | 813      |
# |    total_timesteps  | 4852     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0236   |
# |    n_updates        | 962      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42.7     |
# |    ep_rew_mean      | 42.7     |
# |    exploration_rate | 0.525    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 5        |
# |    time_elapsed     | 839      |
# |    total_timesteps  | 5004     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.01     |
# |    n_updates        | 1000     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42.5     |
# |    ep_rew_mean      | 42.5     |
# |    exploration_rate | 0.511    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 5        |
# |    time_elapsed     | 864      |
# |    total_timesteps  | 5150     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0113   |
# |    n_updates        | 1037     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 41.8     |
# |    ep_rew_mean      | 41.8     |
# |    exploration_rate | 0.496    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 5        |
# |    time_elapsed     | 890      |
# |    total_timesteps  | 5305     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00892  |
# |    n_updates        | 1076     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42.4     |
# |    ep_rew_mean      | 42.4     |
# |    exploration_rate | 0.476    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 5        |
# |    time_elapsed     | 919      |
# |    total_timesteps  | 5512     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00888  |
# |    n_updates        | 1127     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42.6     |
# |    ep_rew_mean      | 42.6     |
# |    exploration_rate | 0.458    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 6        |
# |    time_elapsed     | 948      |
# |    total_timesteps  | 5703     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0114   |
# |    n_updates        | 1175     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42.7     |
# |    ep_rew_mean      | 42.7     |
# |    exploration_rate | 0.443    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 6        |
# |    time_elapsed     | 974      |
# |    total_timesteps  | 5865     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0146   |
# |    n_updates        | 1216     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42.6     |
# |    ep_rew_mean      | 42.6     |
# |    exploration_rate | 0.424    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 6        |
# |    time_elapsed     | 1002     |
# |    total_timesteps  | 6064     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0141   |
# |    n_updates        | 1265     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42.7     |
# |    ep_rew_mean      | 42.7     |
# |    exploration_rate | 0.407    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 6        |
# |    time_elapsed     | 1029     |
# |    total_timesteps  | 6243     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0162   |
# |    n_updates        | 1310     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42.5     |
# |    ep_rew_mean      | 42.5     |
# |    exploration_rate | 0.392    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 6        |
# |    time_elapsed     | 1054     |
# |    total_timesteps  | 6399     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0141   |
# |    n_updates        | 1349     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42.3     |
# |    ep_rew_mean      | 42.3     |
# |    exploration_rate | 0.375    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 6        |
# |    time_elapsed     | 1083     |
# |    total_timesteps  | 6577     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0155   |
# |    n_updates        | 1394     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42.4     |
# |    ep_rew_mean      | 42.4     |
# |    exploration_rate | 0.359    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 6        |
# |    time_elapsed     | 1110     |
# |    total_timesteps  | 6743     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0124   |
# |    n_updates        | 1435     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42.5     |
# |    ep_rew_mean      | 42.5     |
# |    exploration_rate | 0.344    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 6        |
# |    time_elapsed     | 1137     |
# |    total_timesteps  | 6903     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0145   |
# |    n_updates        | 1475     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42       |
# |    ep_rew_mean      | 42       |
# |    exploration_rate | 0.329    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 6        |
# |    time_elapsed     | 1162     |
# |    total_timesteps  | 7060     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0141   |
# |    n_updates        | 1514     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 41.9     |
# |    ep_rew_mean      | 41.9     |
# |    exploration_rate | 0.315    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 6        |
# |    time_elapsed     | 1188     |
# |    total_timesteps  | 7215     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0162   |
# |    n_updates        | 1553     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42.3     |
# |    ep_rew_mean      | 42.3     |
# |    exploration_rate | 0.298    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 6        |
# |    time_elapsed     | 1214     |
# |    total_timesteps  | 7392     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00927  |
# |    n_updates        | 1597     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 41.9     |
# |    ep_rew_mean      | 41.9     |
# |    exploration_rate | 0.283    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 6        |
# |    time_elapsed     | 1241     |
# |    total_timesteps  | 7543     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00684  |
# |    n_updates        | 1635     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42.1     |
# |    ep_rew_mean      | 42.1     |
# |    exploration_rate | 0.265    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 6        |
# |    time_elapsed     | 1266     |
# |    total_timesteps  | 7734     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0094   |
# |    n_updates        | 1683     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42.7     |
# |    ep_rew_mean      | 42.7     |
# |    exploration_rate | 0.246    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 6        |
# |    time_elapsed     | 1294     |
# |    total_timesteps  | 7935     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00977  |
# |    n_updates        | 1733     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 43.1     |
# |    ep_rew_mean      | 43.1     |
# |    exploration_rate | 0.227    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 6        |
# |    time_elapsed     | 1321     |
# |    total_timesteps  | 8135     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0112   |
# |    n_updates        | 1783     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 43       |
# |    ep_rew_mean      | 43       |
# |    exploration_rate | 0.21     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 6        |
# |    time_elapsed     | 1347     |
# |    total_timesteps  | 8313     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0146   |
# |    n_updates        | 1828     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 43.1     |
# |    ep_rew_mean      | 43.1     |
# |    exploration_rate | 0.194    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 6        |
# |    time_elapsed     | 1376     |
# |    total_timesteps  | 8486     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0215   |
# |    n_updates        | 1871     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42.7     |
# |    ep_rew_mean      | 42.7     |
# |    exploration_rate | 0.179    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 6        |
# |    time_elapsed     | 1402     |
# |    total_timesteps  | 8642     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0136   |
# |    n_updates        | 1910     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 43       |
# |    ep_rew_mean      | 43       |
# |    exploration_rate | 0.162    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 6        |
# |    time_elapsed     | 1428     |
# |    total_timesteps  | 8825     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.013    |
# |    n_updates        | 1956     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 43.2     |
# |    ep_rew_mean      | 43.2     |
# |    exploration_rate | 0.143    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 6        |
# |    time_elapsed     | 1455     |
# |    total_timesteps  | 9018     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0151   |
# |    n_updates        | 2004     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 43.7     |
# |    ep_rew_mean      | 43.7     |
# |    exploration_rate | 0.124    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 6        |
# |    time_elapsed     | 1480     |
# |    total_timesteps  | 9225     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0243   |
# |    n_updates        | 2056     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 44.5     |
# |    ep_rew_mean      | 44.5     |
# |    exploration_rate | 0.101    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 6        |
# |    time_elapsed     | 1508     |
# |    total_timesteps  | 9458     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00765  |
# |    n_updates        | 2114     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 45.1     |
# |    ep_rew_mean      | 45.1     |
# |    exploration_rate | 0.0824   |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 6        |
# |    time_elapsed     | 1534     |
# |    total_timesteps  | 9659     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0093   |
# |    n_updates        | 2164     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 45.6     |
# |    ep_rew_mean      | 45.6     |
# |    exploration_rate | 0.0631   |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 6        |
# |    time_elapsed     | 1560     |
# |    total_timesteps  | 9862     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0195   |
# |    n_updates        | 2215     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 45.2     |
# |    ep_rew_mean      | 45.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 6        |
# |    time_elapsed     | 1585     |
# |    total_timesteps  | 10036    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.153    |
# |    n_updates        | 2258     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 44.9     |
# |    ep_rew_mean      | 44.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 6        |
# |    time_elapsed     | 1612     |
# |    total_timesteps  | 10188    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.035    |
# |    n_updates        | 2296     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 45.1     |
# |    ep_rew_mean      | 45.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 6        |
# |    time_elapsed     | 1638     |
# |    total_timesteps  | 10374    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0269   |
# |    n_updates        | 2343     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 44.7     |
# |    ep_rew_mean      | 44.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 6        |
# |    time_elapsed     | 1664     |
# |    total_timesteps  | 10536    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0155   |
# |    n_updates        | 2383     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 44.5     |
# |    ep_rew_mean      | 44.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 6        |
# |    time_elapsed     | 1691     |
# |    total_timesteps  | 10693    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00593  |
# |    n_updates        | 2423     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 44.6     |
# |    ep_rew_mean      | 44.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 6        |
# |    time_elapsed     | 1716     |
# |    total_timesteps  | 10857    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0104   |
# |    n_updates        | 2464     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 44.6     |
# |    ep_rew_mean      | 44.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 6        |
# |    time_elapsed     | 1742     |
# |    total_timesteps  | 11042    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00128  |
# |    n_updates        | 2510     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 44.7     |
# |    ep_rew_mean      | 44.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 6        |
# |    time_elapsed     | 1768     |
# |    total_timesteps  | 11209    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00587  |
# |    n_updates        | 2552     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 44.6     |
# |    ep_rew_mean      | 44.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 6        |
# |    time_elapsed     | 1793     |
# |    total_timesteps  | 11367    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00765  |
# |    n_updates        | 2591     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 44.6     |
# |    ep_rew_mean      | 44.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 6        |
# |    time_elapsed     | 1819     |
# |    total_timesteps  | 11520    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0102   |
# |    n_updates        | 2629     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 44.5     |
# |    ep_rew_mean      | 44.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 6        |
# |    time_elapsed     | 1845     |
# |    total_timesteps  | 11670    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00925  |
# |    n_updates        | 2667     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 44.6     |
# |    ep_rew_mean      | 44.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 6        |
# |    time_elapsed     | 1870     |
# |    total_timesteps  | 11853    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.014    |
# |    n_updates        | 2713     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 45       |
# |    ep_rew_mean      | 45       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 6        |
# |    time_elapsed     | 1896     |
# |    total_timesteps  | 12038    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00614  |
# |    n_updates        | 2759     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 44.6     |
# |    ep_rew_mean      | 44.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 6        |
# |    time_elapsed     | 1921     |
# |    total_timesteps  | 12197    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0136   |
# |    n_updates        | 2799     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 44.5     |
# |    ep_rew_mean      | 44.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 6        |
# |    time_elapsed     | 1947     |
# |    total_timesteps  | 12383    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0129   |
# |    n_updates        | 2845     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 44.1     |
# |    ep_rew_mean      | 44.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 6        |
# |    time_elapsed     | 1973     |
# |    total_timesteps  | 12550    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00282  |
# |    n_updates        | 2887     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 44       |
# |    ep_rew_mean      | 44       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 6        |
# |    time_elapsed     | 1998     |
# |    total_timesteps  | 12709    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0141   |
# |    n_updates        | 2927     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 43.9     |
# |    ep_rew_mean      | 43.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 6        |
# |    time_elapsed     | 2024     |
# |    total_timesteps  | 12874    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00247  |
# |    n_updates        | 2968     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 43.9     |
# |    ep_rew_mean      | 43.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 6        |
# |    time_elapsed     | 2050     |
# |    total_timesteps  | 13032    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00798  |
# |    n_updates        | 3007     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 44       |
# |    ep_rew_mean      | 44       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 6        |
# |    time_elapsed     | 2076     |
# |    total_timesteps  | 13224    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0165   |
# |    n_updates        | 3055     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 43.8     |
# |    ep_rew_mean      | 43.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 6        |
# |    time_elapsed     | 2101     |
# |    total_timesteps  | 13393    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00373  |
# |    n_updates        | 3098     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 43.4     |
# |    ep_rew_mean      | 43.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 6        |
# |    time_elapsed     | 2127     |
# |    total_timesteps  | 13561    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00851  |
# |    n_updates        | 3140     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42.7     |
# |    ep_rew_mean      | 42.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 6        |
# |    time_elapsed     | 2152     |
# |    total_timesteps  | 13730    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00369  |
# |    n_updates        | 3182     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42.4     |
# |    ep_rew_mean      | 42.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 6        |
# |    time_elapsed     | 2178     |
# |    total_timesteps  | 13902    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0094   |
# |    n_updates        | 3225     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 41.9     |
# |    ep_rew_mean      | 41.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 6        |
# |    time_elapsed     | 2203     |
# |    total_timesteps  | 14053    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00469  |
# |    n_updates        | 3263     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42.1     |
# |    ep_rew_mean      | 42.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 6        |
# |    time_elapsed     | 2229     |
# |    total_timesteps  | 14242    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00773  |
# |    n_updates        | 3310     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42.2     |
# |    ep_rew_mean      | 42.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 6        |
# |    time_elapsed     | 2254     |
# |    total_timesteps  | 14408    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00731  |
# |    n_updates        | 3351     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42       |
# |    ep_rew_mean      | 42       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 6        |
# |    time_elapsed     | 2280     |
# |    total_timesteps  | 14578    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00325  |
# |    n_updates        | 3394     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 41.9     |
# |    ep_rew_mean      | 41.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 6        |
# |    time_elapsed     | 2306     |
# |    total_timesteps  | 14729    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00809  |
# |    n_updates        | 3432     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42       |
# |    ep_rew_mean      | 42       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 6        |
# |    time_elapsed     | 2332     |
# |    total_timesteps  | 14897    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00252  |
# |    n_updates        | 3474     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42       |
# |    ep_rew_mean      | 42       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 6        |
# |    time_elapsed     | 2357     |
# |    total_timesteps  | 15059    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00688  |
# |    n_updates        | 3514     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 41.8     |
# |    ep_rew_mean      | 41.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 6        |
# |    time_elapsed     | 2383     |
# |    total_timesteps  | 15219    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00283  |
# |    n_updates        | 3554     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42       |
# |    ep_rew_mean      | 42       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 6        |
# |    time_elapsed     | 2408     |
# |    total_timesteps  | 15407    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000974 |
# |    n_updates        | 3601     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42.1     |
# |    ep_rew_mean      | 42.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 6        |
# |    time_elapsed     | 2433     |
# |    total_timesteps  | 15582    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00678  |
# |    n_updates        | 3645     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42.1     |
# |    ep_rew_mean      | 42.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 6        |
# |    time_elapsed     | 2459     |
# |    total_timesteps  | 15733    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00334  |
# |    n_updates        | 3683     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42.4     |
# |    ep_rew_mean      | 42.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 6        |
# |    time_elapsed     | 2485     |
# |    total_timesteps  | 15912    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0302   |
# |    n_updates        | 3727     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42.2     |
# |    ep_rew_mean      | 42.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 6        |
# |    time_elapsed     | 2511     |
# |    total_timesteps  | 16074    |
# ...
# |    time_elapsed     | 13056    |
# |    total_timesteps  | 89001    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.248    |
# |    n_updates        | 22000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 69.3     |
# |    ep_rew_mean      | 69.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1560     |
# |    fps              | 6        |
# |    time_elapsed     | 13092    |
# |    total_timesteps  | 89299    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.036    |
# |    n_updates        | 22074    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 69.5     |
# |    ep_rew_mean      | 69.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1564     |
# |    fps              | 6        |
# |    time_elapsed     | 13128    |
# |    total_timesteps  | 89540    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0803   |
# |    n_updates        | 22134    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 70.9     |
# |    ep_rew_mean      | 70.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1568     |
# |    fps              | 6        |
# |    time_elapsed     | 13182    |
# |    total_timesteps  | 89965    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.203    |
# |    n_updates        | 22241    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 71.8     |
# |    ep_rew_mean      | 71.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1572     |
# |    fps              | 6        |
# |    time_elapsed     | 13221    |
# |    total_timesteps  | 90269    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0429   |
# |    n_updates        | 22317    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 74.3     |
# |    ep_rew_mean      | 74.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1576     |
# |    fps              | 6        |
# |    time_elapsed     | 13284    |
# |    total_timesteps  | 90792    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.112    |
# |    n_updates        | 22447    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 74.6     |
# |    ep_rew_mean      | 74.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1580     |
# |    fps              | 6        |
# |    time_elapsed     | 13328    |
# |    total_timesteps  | 91117    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0348   |
# |    n_updates        | 22529    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 76.2     |
# |    ep_rew_mean      | 76.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1584     |
# |    fps              | 6        |
# |    time_elapsed     | 13379    |
# |    total_timesteps  | 91517    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.104    |
# |    n_updates        | 22629    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 78       |
# |    ep_rew_mean      | 78       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1588     |
# |    fps              | 6        |
# |    time_elapsed     | 13430    |
# |    total_timesteps  | 91950    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0597   |
# |    n_updates        | 22737    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81       |
# |    ep_rew_mean      | 81       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1592     |
# |    fps              | 6        |
# |    time_elapsed     | 13495    |
# |    total_timesteps  | 92486    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.04     |
# |    n_updates        | 22871    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 83.3     |
# |    ep_rew_mean      | 83.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1596     |
# |    fps              | 6        |
# |    time_elapsed     | 13546    |
# |    total_timesteps  | 92912    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0129   |
# |    n_updates        | 22977    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81.6     |
# |    ep_rew_mean      | 81.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1600     |
# |    fps              | 6        |
# |    time_elapsed     | 13577    |
# |    total_timesteps  | 93160    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0813   |
# |    n_updates        | 23039    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 80.7     |
# |    ep_rew_mean      | 80.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1604     |
# |    fps              | 6        |
# |    time_elapsed     | 13607    |
# |    total_timesteps  | 93358    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0813   |
# |    n_updates        | 23089    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 82.7     |
# |    ep_rew_mean      | 82.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1608     |
# |    fps              | 6        |
# |    time_elapsed     | 13662    |
# |    total_timesteps  | 93809    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0218   |
# |    n_updates        | 23202    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 83.8     |
# |    ep_rew_mean      | 83.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1612     |
# |    fps              | 6        |
# |    time_elapsed     | 13712    |
# |    total_timesteps  | 94194    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00541  |
# |    n_updates        | 23298    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 83.8     |
# |    ep_rew_mean      | 83.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1616     |
# |    fps              | 6        |
# |    time_elapsed     | 13748    |
# |    total_timesteps  | 94485    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0942   |
# |    n_updates        | 23371    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 84.1     |
# |    ep_rew_mean      | 84.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1620     |
# |    fps              | 6        |
# |    time_elapsed     | 13781    |
# |    total_timesteps  | 94733    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.176    |
# |    n_updates        | 23433    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 84.1     |
# |    ep_rew_mean      | 84.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1624     |
# |    fps              | 6        |
# |    time_elapsed     | 13830    |
# |    total_timesteps  | 95125    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.222    |
# |    n_updates        | 23531    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 84.7     |
# |    ep_rew_mean      | 84.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1628     |
# |    fps              | 6        |
# |    time_elapsed     | 13873    |
# |    total_timesteps  | 95497    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.187    |
# |    n_updates        | 23624    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.2     |
# |    ep_rew_mean      | 86.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1632     |
# |    fps              | 6        |
# |    time_elapsed     | 13918    |
# |    total_timesteps  | 95839    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.21     |
# |    n_updates        | 23709    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.9     |
# |    ep_rew_mean      | 87.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1636     |
# |    fps              | 6        |
# |    time_elapsed     | 13971    |
# |    total_timesteps  | 96273    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0573   |
# |    n_updates        | 23818    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89       |
# |    ep_rew_mean      | 89       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1640     |
# |    fps              | 6        |
# |    time_elapsed     | 14010    |
# |    total_timesteps  | 96566    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0113   |
# |    n_updates        | 23891    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91       |
# |    ep_rew_mean      | 91       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1644     |
# |    fps              | 6        |
# |    time_elapsed     | 14072    |
# |    total_timesteps  | 97094    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.284    |
# |    n_updates        | 24023    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.7     |
# |    ep_rew_mean      | 90.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1648     |
# |    fps              | 6        |
# |    time_elapsed     | 14121    |
# |    total_timesteps  | 97487    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.133    |
# |    n_updates        | 24121    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.2     |
# |    ep_rew_mean      | 90.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1652     |
# |    fps              | 6        |
# |    time_elapsed     | 14156    |
# |    total_timesteps  | 97748    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0343   |
# |    n_updates        | 24186    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.1     |
# |    ep_rew_mean      | 91.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1656     |
# |    fps              | 6        |
# |    time_elapsed     | 14202    |
# |    total_timesteps  | 98115    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.11     |
# |    n_updates        | 24278    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.1     |
# |    ep_rew_mean      | 91.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1660     |
# |    fps              | 6        |
# |    time_elapsed     | 14238    |
# |    total_timesteps  | 98407    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0461   |
# |    n_updates        | 24351    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92       |
# |    ep_rew_mean      | 92       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1664     |
# |    fps              | 6        |
# |    time_elapsed     | 14281    |
# |    total_timesteps  | 98742    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.156    |
# |    n_updates        | 24435    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.2     |
# |    ep_rew_mean      | 91.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1668     |
# |    fps              | 6        |
# |    time_elapsed     | 14328    |
# |    total_timesteps  | 99089    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0113   |
# |    n_updates        | 24522    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.3     |
# |    ep_rew_mean      | 92.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1672     |
# |    fps              | 6        |
# |    time_elapsed     | 14379    |
# |    total_timesteps  | 99502    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.181    |
# |    n_updates        | 24625    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.3     |
# |    ep_rew_mean      | 89.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1676     |
# |    fps              | 6        |
# |    time_elapsed     | 14412    |
# |    total_timesteps  | 99726    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0569   |
# |    n_updates        | 24681    |
# ----------------------------------

# %%
for episode in range(10):
    obs = env.reset()[0]
    done = False
    total_reward = 0
    while not done:
        action, _states = model.predict(obs)
        print(action) 
        obs, reward, done, oui, info = env.step(int(action))
        total_reward += reward
    print(f'Episode {episode} Total Reward: {total_reward}')
